# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Weather_1997-2015.csv")

# %%
df["na_values"]=df.isna().sum(axis=1)
df
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0     1997-01-01               7.0                4.0               2.0
# 1     1997-01-02               7.0                3.0               0.0
# 2     1997-01-03               5.0                3.0               2.0
# 3     1997-01-04               7.0                3.0              -1.0
# 4     1997-01-05               2.0                0.0              -1.0
# ...          ...               ...                ...               ...
# 6807  2015-12-27              14.0                7.0              -1.0
# 6808  2015-12-28              15.0                8.0               2.0
# 6809  2015-12-29              11.0                8.0               5.0
# 6810  2015-12-30               9.0                8.0               6.0
# 6811  2015-12-31              12.0               10.0               7.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
df[['Max TemperatureC','Min TemperatureC']]
# Out:
#       Max TemperatureC  Min TemperatureC
# 0                  7.0               2.0
# 1                  7.0               0.0
# 2                  5.0               2.0
# 3                  7.0              -1.0
# 4                  2.0              -1.0
# ...                ...               ...
# 6807              14.0              -1.0
# 6808              15.0               2.0
# 6809              11.0               5.0
# 6810               9.0               6.0
# 6811              12.0               7.0
#
# [6812 rows x 2 columns]

# %%
df[df['Min TemperatureC']<0]
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 3     1997-01-04               7.0                3.0              -1.0
# 4     1997-01-05               2.0                0.0              -1.0
# 6     1997-01-07               2.0                0.0              -2.0
# 39    1997-02-09              14.0                7.0              -1.0
# 46    1997-02-16              15.0                7.0              -1.0
# ...          ...               ...                ...               ...
# 6782  2015-12-02              15.0                7.0              -1.0
# 6783  2015-12-03              17.0                8.0              -1.0
# 6805  2015-12-25              14.0                6.0              -2.0
# 6806  2015-12-26              12.0                6.0              -1.0
# 6807  2015-12-27              14.0                7.0              -1.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# ...

# %%
df[df['Max TemperatureC']==df['Max TemperatureC'].max()]
# Out:
#              CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 5573  2012-08-10              41.0               30.0              20.0
#
#       Dew PointC  MeanDew PointC  Min DewpointC  Max Humidity   Mean Humidity  \
# 5573         7.0             5.0            3.0          38.0            20.0
#
#        Min Humidity  ...   Mean VisibilityKm   Min VisibilitykM  \
# 5573            6.0  ...                12.0               10.0
#
#        Max Wind SpeedKm/h   Mean Wind SpeedKm/h   Max Gust SpeedKm/h  \
# 5573                   42                    10                 39.0
#
#       Precipitationmm   CloudCover   Events  WindDirDegrees  na_values
# 5573              0.0          1.0      NaN             338          1
#
# [1 rows x 24 columns]

# %%
df[['Max TemperatureC','CET']][df['Max TemperatureC']==df['Max TemperatureC'].max()]
# Out:
#       Max TemperatureC         CET
# 5573              41.0  2012-08-10

# %%
df.index
# Out:
# RangeIndex(start=0, stop=6812, step=1)

# %%
df.loc[0]
# Out:
# CET                            1997-01-01
# Max TemperatureC                      7.0
# Mean TemperatureC                     4.0
# Min TemperatureC                      2.0
# Dew PointC                            5.0
# MeanDew PointC                        3.0
# Min DewpointC                         2.0
# Max Humidity                        100.0
#  Mean Humidity                       95.0
#  Min Humidity                        76.0
#  Max Sea Level PressurehPa           1010
#  Mean Sea Level PressurehPa          1008
#  Min Sea Level PressurehPa           1004
#  Max VisibilityKm                    10.0
#  Mean VisibilityKm                    9.0
#  Min VisibilitykM                     4.0
#  Max Wind SpeedKm/h                    13
#  Mean Wind SpeedKm/h                    6
#  Max Gust SpeedKm/h                   NaN
# Precipitationmm                       0.0
#  CloudCover                           6.0
#  Events                               NaN
# ...

# %%
df.fillna("Not Available",inplace=True)
# Out:
# /tmp/ipykernel_19560/3301399259.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Available' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("Not Available",inplace=True)

# %%
df.to_csv("test.csv",index=False)
df.to_excel("test.xlsx",index=False)

# %%
df.to_csv("test.csv",index=False,header=False,columns=["CET","Max TemperatureC"])

# %%
spotify=pd.read_csv("spotify_history.csv")
weather=pd.read_csv("Weather_1997-2015.csv")
with pd.ExcelWriter("sheets.xlsx") as writer:
    spotify.to_excel(writer,sheet_name="spotify")
    weather.to_excel(writer,sheet_name="weather")

# %%
df[' CloudCover']=df[" CloudCover"].ffill()
df[[' CloudCover']].head(45)
# Out:
#     CloudCover
# 0          6.0
# 1          5.0
# 2          6.0
# 3          2.0
# 4          7.0
# 5          4.0
# 6          7.0
# 7          7.0
# 8          4.0
# 9          5.0
# 10         3.0
# 11         1.0
# 12         4.0
# 13         4.0
# 14         6.0
# 15         6.0
# 16         4.0
# 17         6.0
# 18         4.0
# 19         5.0
# 20         5.0
# 21         5.0
# 22         7.0
# 23         5.0
# 24         6.0
# 25         2.0
# 26         6.0
# 27         3.0
# 28         7.0
# 29         5.0
# 30         3.0
# 31         3.0
# 32         5.0
# 33         4.0
# 34         1.0
# 35         2.0
# 36         3.0
# 37         3.0
# 38         6.0
# 39         1.0
# 40         1.0
# 41         2.0
# 42         1.0
# 43         3.0
# 44         4.0

# %%
df=pd.read_csv("Weather_1997-2015.csv")

df[' CloudCover']=df[" CloudCover"].bfill()
df[[' CloudCover']].head(45)
# Out:
#     CloudCover
# 0          6.0
# 1          5.0
# 2          6.0
# 3          2.0
# 4          7.0
# 5          4.0
# 6          7.0
# 7          7.0
# 8          4.0
# 9          5.0
# 10         3.0
# 11         1.0
# 12         4.0
# 13         4.0
# 14         6.0
# 15         6.0
# 16         4.0
# 17         6.0
# 18         4.0
# 19         5.0
# 20         5.0
# 21         5.0
# 22         7.0
# 23         5.0
# 24         6.0
# 25         2.0
# 26         6.0
# 27         3.0
# 28         7.0
# 29         5.0
# 30         3.0
# 31         3.0
# 32         5.0
# 33         4.0
# 34         1.0
# 35         2.0
# 36         3.0
# 37         3.0
# 38         6.0
# 39         1.0
# 40         2.0
# 41         2.0
# 42         1.0
# 43         3.0
# 44         4.0

# %%
df=pd.read_csv("Weather_1997-2015.csv")

df[' CloudCover']=df[" CloudCover"].interpolate()
df[[' CloudCover']].head(45)
# Out:
#     CloudCover
# 0          6.0
# 1          5.0
# 2          6.0
# 3          2.0
# 4          7.0
# 5          4.0
# 6          7.0
# 7          7.0
# 8          4.0
# 9          5.0
# 10         3.0
# 11         1.0
# 12         4.0
# 13         4.0
# 14         6.0
# 15         6.0
# 16         4.0
# 17         6.0
# 18         4.0
# 19         5.0
# 20         5.0
# 21         5.0
# 22         7.0
# 23         5.0
# 24         6.0
# 25         2.0
# 26         6.0
# 27         3.0
# 28         7.0
# 29         5.0
# 30         3.0
# 31         3.0
# 32         5.0
# 33         4.0
# 34         1.0
# 35         2.0
# 36         3.0
# 37         3.0
# 38         6.0
# 39         1.0
# 40         1.5
# 41         2.0
# 42         1.0
# 43         3.0
# 44         4.0

# %%
df=pd.read_csv("Weather_1997-2015.csv")
df.head(45)
# Out:
#            CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0   1997-01-01               7.0                4.0               2.0
# 1   1997-01-02               7.0                3.0               0.0
# 2   1997-01-03               5.0                3.0               2.0
# 3   1997-01-04               7.0                3.0              -1.0
# 4   1997-01-05               2.0                0.0              -1.0
# 5   1997-01-06               7.0                3.0               1.0
# 6   1997-01-07               2.0                0.0              -2.0
# 7   1997-01-08               8.0                4.0               1.0
# 8   1997-01-09              12.0               10.0               8.0
# 9   1997-01-10              13.0                8.0               3.0
# 10  1997-01-11              16.0               10.0               5.0
# 11  1997-01-12              17.0               10.0               3.0
# ...

# %%
df_t=df.replace(
    {
        "CloudCover":-99999,
        "Events":"No Events"
    },np.nan
)
df_t.head(45)
# Out:
#            CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0   1997-01-01               7.0                4.0               2.0
# 1   1997-01-02               7.0                3.0               0.0
# 2   1997-01-03               5.0                3.0               2.0
# 3   1997-01-04               7.0                3.0              -1.0
# 4   1997-01-05               2.0                0.0              -1.0
# 5   1997-01-06               7.0                3.0               1.0
# 6   1997-01-07               2.0                0.0              -2.0
# 7   1997-01-08               8.0                4.0               1.0
# 8   1997-01-09              12.0               10.0               8.0
# 9   1997-01-10              13.0                8.0               3.0
# 10  1997-01-11              16.0               10.0               5.0
# 11  1997-01-12              17.0               10.0               3.0
# ...

# %%
df_t=df.replace(
    {
        ' CloudCover':'[0-9]'
    },100,regex=True
)
df_t.head(45)
# Out:
#            CET  Max TemperatureC  Mean TemperatureC  Min TemperatureC  \
# 0   1997-01-01               7.0                4.0               2.0
# 1   1997-01-02               7.0                3.0               0.0
# 2   1997-01-03               5.0                3.0               2.0
# 3   1997-01-04               7.0                3.0              -1.0
# 4   1997-01-05               2.0                0.0              -1.0
# 5   1997-01-06               7.0                3.0               1.0
# 6   1997-01-07               2.0                0.0              -2.0
# 7   1997-01-08               8.0                4.0               1.0
# 8   1997-01-09              12.0               10.0               8.0
# 9   1997-01-10              13.0                8.0               3.0
# 10  1997-01-11              16.0               10.0               5.0
# 11  1997-01-12              17.0               10.0               3.0
# ...
