# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('./spotify_history.csv')

print(df.head(10))
print(df.tail(10))
print(df.size)
print(df.shape)
print(df.columns)
# Out:
#         spotify_track_uri                   ts    platform  ms_played  \
# 0  2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1  1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2  487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3  5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4  0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# 5  50VNvhzyaSplJCKWchN7a8  2013-07-08 03:17:52  web player      63485
# 6  1I4EczxGBcPR3J3KeyqFJP  2013-07-08 03:17:56  web player          0
# 7  5arVt2Wg0zbiWwAOZef2Nl  2013-07-08 03:17:56  web player       1268
# 8  1ixtaZc0Adil3yD1ItPqSl  2013-07-08 03:17:58  web player          0
# 9  2v5mpowLQNFN7NC46l0bJS  2013-07-08 03:19:11  web player          0
#
#                                       track_name            artist_name  \
# 0                            Say It, Just Say It           The Mowgli's
# 1  Drinking from the Bottle (feat. Tinie Tempah)          Calvin Harris
# 2                                    Born To Die           Lana Del Rey
# 3                               Off To The Races           Lana Del Rey
# 4                                      Half Mast      Empire Of The Sun
# 5                                     Impossible           James Arthur
# 6                                 We Own The Sky                    M83
# 7                Higher Ground - Remastered 2003  Red Hot Chili Peppers
# 8                                  Happy Up Here               Röyksopp
# 9                                        Phantom                Justice
#
#                            album_name reason_start reason_end  shuffle  \
# 0                Waiting For The Dawn     autoplay   clickrow    False
# 1                           18 Months     clickrow   clickrow    False
# 2  Born To Die - The Paradise Edition     clickrow    unknown    False
# 3  Born To Die - The Paradise Edition    trackdone   clickrow    False
# 4                  Walking On A Dream     clickrow    nextbtn    False
# 5                          Impossible     clickrow   clickrow    False
# 6                   Saturdays = Youth      nextbtn    nextbtn    False
# 7                       Mother's Milk      nextbtn    nextbtn    False
# 8                       Happy Up Here      nextbtn    nextbtn    False
# 9                             Phantom      nextbtn   clickrow    False
#
#    skipped
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
#              spotify_track_uri                   ts platform  ms_played  \
# 149850  4GAhAw0RCzNVP976NRMOqO  2024-12-15 23:06:09  android       1869
# 149851  1yxJyuOyBzOXbGDAZtT7BD  2024-12-15 23:06:10  android       1342
# 149852  2BdBVq6So5sBCbALS2p1rR  2024-12-15 23:06:15  android       4216
# 149853  76CfWxdNh9k5ssABTxlmMJ  2024-12-15 23:06:16  android       1375
# 149854  52dm9op3rbfAkc1LGXgipW  2024-12-15 23:06:18  android       1562
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19  android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21  android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22  android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23  android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25  android       1893
#
#                                                track_name         artist_name  \
# 149850  Love Me Tender - From the 20th Century-Fox Cin...       Elvis Presley
# 149851                                          Who Cares      Paul McCartney
# 149852              I'm the Only Hell My Mama Ever Raised       Willie Nelson
# 149853                    Eight Line Poem - 2015 Remaster         David Bowie
# 149854                             Wild Horses - 2009 Mix  The Rolling Stones
# 149855                                    On The Way Home          John Mayer
# 149856             Magical Mystery Tour - Remastered 2009         The Beatles
# 149857  Stop This Train - Live at the Nokia Theatre, L...          John Mayer
# 149858             I Don't Trust Myself (With Loving You)          John Mayer
# 149859                              God Only Knows - Mono      The Beach Boys
#
#                                                album_name reason_start  \
# 149850                              Elvis' Golden Records       fwdbtn
# 149851                                      Egypt Station       fwdbtn
# 149852                               First Rose of Spring       fwdbtn
# 149853                                         Hunky Dory       fwdbtn
# 149854                                     Sticky Fingers       fwdbtn
# 149855                                    Paradise Valley       fwdbtn
# 149856                               Magical Mystery Tour       fwdbtn
# 149857  Where the Light Is: John Mayer Live In Los Ang...       fwdbtn
# 149858                                          Continuum       fwdbtn
# 149859                                         Pet Sounds       fwdbtn
#
#        reason_end  shuffle  skipped
# 149850     fwdbtn     True     True
# 149851     fwdbtn     True     True
# 149852     fwdbtn     True     True
# 149853     fwdbtn     True     True
# 149854     fwdbtn     True     True
# 149855     fwdbtn     True     True
# 149856     fwdbtn     True     True
# 149857     fwdbtn     True     True
# 149858     fwdbtn     True     True
# 149859     fwdbtn     True     True
# 1648460
# (149860, 11)
# Index(['spotify_track_uri', 'ts', 'platform', 'ms_played', 'track_name',
#        'artist_name', 'album_name', 'reason_start', 'reason_end', 'shuffle',
#        'skipped'],
#       dtype='object')

# %%
# Display basic statistics of the dataframe
print(df.describe())

# Check for missing values
print(df.isnull().sum())

# Display the distribution of the 'platform' column
print(df['platform'].value_counts())
# Out:
#           ms_played
# count  1.498600e+05
# mean   1.283166e+05
# std    1.178401e+05
# min    0.000000e+00
# 25%    2.795000e+03
# 50%    1.388400e+05
# 75%    2.185070e+05
# max    1.561125e+06
# spotify_track_uri      0
# ts                     0
# platform               0
# ms_played              0
# track_name             0
# artist_name            0
# album_name             0
# reason_start         143
# reason_end           117
# shuffle                0
# skipped                0
# dtype: int64
# platform
# android           139821
# cast to device      3898
# iOS                 3049
# windows             1691
# mac                 1176
# web player           225
# Name: count, dtype: int64

# %%
df.to_pickle("f.pkl")

# %%
pkl=pd.read_pickle("./f.pkl")
pkl
# Out:
#              spotify_track_uri                   ts    platform  ms_played  \
# 0       2J3n32GeLmMjwuAzyhcSNe  2013-07-08 02:44:34  web player       3185
# 1       1oHxIPqJyvAYHy0PVrDU98  2013-07-08 02:45:37  web player      61865
# 2       487OPlneJNni3NWC8SYqhW  2013-07-08 02:50:24  web player     285386
# 3       5IyblF777jLZj1vGHG2UD3  2013-07-08 02:52:40  web player     134022
# 4       0GgAAB0ZMllFhbNc3mAodO  2013-07-08 03:17:52  web player          0
# ...                        ...                  ...         ...        ...
# 149855  4Fz1WWr5o0OrlIcZxcyZtK  2024-12-15 23:06:19     android       1247
# 149856  0qHMhBZqYb99yhX9BHcIkV  2024-12-15 23:06:21     android       1515
# 149857  0HHdujGjOZChTrl8lJWEIq  2024-12-15 23:06:22     android       1283
# 149858  7peh6LUcdNPcMdrSH4JPsM  2024-12-15 23:06:23     android       1306
# 149859  6iGU74CwXuT4XVepjc9Emf  2024-12-15 23:06:25     android       1893
#
#                                                track_name        artist_name  \
# 0                                     Say It, Just Say It       The Mowgli's
# 1           Drinking from the Bottle (feat. Tinie Tempah)      Calvin Harris
# 2                                             Born To Die       Lana Del Rey
# 3                                        Off To The Races       Lana Del Rey
# 4                                               Half Mast  Empire Of The Sun
# ...                                                   ...                ...
# 149855                                    On The Way Home         John Mayer
# 149856             Magical Mystery Tour - Remastered 2009        The Beatles
# 149857  Stop This Train - Live at the Nokia Theatre, L...         John Mayer
# 149858             I Don't Trust Myself (With Loving You)         John Mayer
# 149859                              God Only Knows - Mono     The Beach Boys
#
#                                                album_name reason_start  \
# 0                                    Waiting For The Dawn     autoplay
# 1                                               18 Months     clickrow
# 2                      Born To Die - The Paradise Edition     clickrow
# 3                      Born To Die - The Paradise Edition    trackdone
# 4                                      Walking On A Dream     clickrow
# ...                                                   ...          ...
# 149855                                    Paradise Valley       fwdbtn
# 149856                               Magical Mystery Tour       fwdbtn
# 149857  Where the Light Is: John Mayer Live In Los Ang...       fwdbtn
# 149858                                          Continuum       fwdbtn
# 149859                                         Pet Sounds       fwdbtn
#
#        reason_end  shuffle  skipped
# 0        clickrow    False    False
# 1        clickrow    False    False
# 2         unknown    False    False
# 3        clickrow    False    False
# 4         nextbtn    False    False
# ...           ...      ...      ...
# 149855     fwdbtn     True     True
# 149856     fwdbtn     True     True
# 149857     fwdbtn     True     True
# 149858     fwdbtn     True     True
# 149859     fwdbtn     True     True
#
# [149860 rows x 11 columns]

# %%
df.to_csv("df.csv")

# %%
clipboad=pd.read_clipboard(sep="\s+")
print(clipboad)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipykernel_7028/4231633978.py:1: SyntaxWarning: invalid escape sequence '\s'
#   clipboad=pd.read_clipboard(sep="\s+")
# /tmp/ipykernel_7028/4231633978.py:1: SyntaxWarning: invalid escape sequence '\s'
#   clipboad=pd.read_clipboard(sep="\s+")
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 clipboad=pd.read_clipboard(sep="\s+")
#       2 print(clipboad)
#
# File ~/Documents/Pandas/venv_pandas/lib/python3.12/site-packages/pandas/io/clipboards.py:86, in read_clipboard(sep, dtype_backend, **kwargs)
#      83 from pandas.io.clipboard import clipboard_get
#      84 from pandas.io.parsers import read_csv
# ---> 86 text = clipboard_get()
#      88 # Try to decode (if needed, as "text" might already be a string here).
#      89 try:
#
# File ~/Documents/Pandas/venv_pandas/lib/python3.12/site-packages/pandas/io/clipboard/__init__.py:681, in lazy_load_stub_paste()
#     679 global copy, paste
#     680 copy, paste = determine_clipboard()
# --> 681 return paste()
#
# File ~/Documents/Pandas/venv_pandas/lib/python3.12/site-packages/pandas/io/clipboard/__init__.py:316, in init_no_clipboard.<locals>.ClipboardUnavailable.__call__(self, *args, **kwargs)
#     315 def __call__(self, *args, **kwargs):
# --> 316     raise PyperclipException(EXCEPT_MSG)
#
# PyperclipException:
#     Pyperclip could not find a copy/paste mechanism for your system.
#     For more information, please visit
#     https://pyperclip.readthedocs.io/en/latest/index.html#not-implemented-error
